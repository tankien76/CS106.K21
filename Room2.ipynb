# %% [markdown]
# <a href="https://colab.research.google.com/github/tankien76/CS106.K21/blob/master/Room2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip "/content/drive/My Drive/room.zip" -d "dataset"

# %%
import os
import cv2
from sklearn import preprocessing
from pathlib import Path

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import cv2
from tensorflow.keras.preprocessing import image
from zipfile import ZipFile

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
test_dir="dataset/images/val"
train_dir="dataset/images/train"

train_dir_clean = train_dir + '/clean'
train_dir_messy = train_dir + '/messy'
test_dir_clean = test_dir + '/clean'
test_dir_messy = test_dir + '/messy'

# %%
print('number of clean training images - ',len(os.listdir(train_dir_clean)))
print('number of messy training images - ',len(os.listdir(train_dir_messy)))
print('number of clean testing images - ',len(os.listdir(test_dir_clean)))
print('number of messy testing images - ',len(os.listdir(test_dir_messy)))
# Out:
# number of clean training images -  160
# number of messy training images -  169
# number of clean testing images -  37
# number of messy testing images -  32

# %%
data_generator = ImageDataGenerator(rescale = 1.0/255.0, zoom_range = 0.2)

# %%
batch_size = 32
training_data = data_generator.flow_from_directory(directory = train_dir,
                                                   target_size = (64, 64),
                                                   batch_size = batch_size,
                                                   class_mode = 'binary')
testing_data = data_generator.flow_from_directory(directory = test_dir,
                                                  target_size = (64, 64),
                                                  batch_size = batch_size,
                                                  class_mode = 'binary')
# Out:
# Found 329 images belonging to 2 classes.
# Found 69 images belonging to 2 classes.

# %%
# preparing the layers in the Convolutional Deep Neural Network
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu', input_shape = training_data.image_shape))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(rate = 0.3))
model.add(Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(rate = 0.2))
model.add(Conv2D(filters = 126, kernel_size = (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(rate = 0.15))
model.add(Flatten())
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dropout(rate = 0.15))
model.add(Dense(units = 64, activation = 'relu'))
model.add(Dropout(rate = 0.1))
model.add(Dense(units = len(set(training_data.classes)), activation = 'softmax'))
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 126)       72702
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 126)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 126)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4536)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                145184
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 239,520
# Trainable params: 239,520
# Non-trainable params: 0
# _________________________________________________________________

# %%
fitted_model = model.fit_generator(training_data,
                        epochs = 25,
                        validation_data = testing_data)
# Out:
# WARNING:tensorflow:From <ipython-input-11-1a4847a3666c>:3: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/25
# 11/11 [==============================] - 7s 624ms/step - loss: 0.7057 - accuracy: 0.4833 - val_loss: 0.6903 - val_accuracy: 0.4638
# Epoch 2/25
# 11/11 [==============================] - 7s 623ms/step - loss: 0.6917 - accuracy: 0.5198 - val_loss: 0.6813 - val_accuracy: 0.4783
# Epoch 3/25
# 11/11 [==============================] - 6s 582ms/step - loss: 0.6308 - accuracy: 0.6748 - val_loss: 0.5271 - val_accuracy: 0.7971
# Epoch 4/25
# 11/11 [==============================] - 7s 615ms/step - loss: 0.5080 - accuracy: 0.7538 - val_loss: 0.3047 - val_accuracy: 0.8696
# Epoch 5/25
# 11/11 [==============================] - 7s 626ms/step - loss: 0.4408 - accuracy: 0.7933 - val_loss: 0.2980 - val_accuracy: 0.9275
# Epoch 6/25
# 11/11 [==============================] - 6s 586ms/step - loss: 0.4227 - accuracy: 0.8419 - val_loss: 0.2897 - val_accuracy: 0.9420
# Epoch 7/25
# 11/11 [==============================] - 7s 600ms/step - loss: 0.4100 - accuracy: 0.8328 - val_loss: 0.2844 - val_accuracy: 0.9420
# Epoch 8/25
# 11/11 [==============================] - 7s 603ms/step - loss: 0.4042 - accuracy: 0.8328 - val_loss: 0.2606 - val_accuracy: 0.9420
# Epoch 9/25
# 11/11 [==============================] - 7s 615ms/step - loss: 0.4539 - accuracy: 0.7903 - val_loss: 0.2935 - val_accuracy: 0.9710
# Epoch 10/25
# 11/11 [==============================] - 6s 582ms/step - loss: 0.4874 - accuracy: 0.7660 - val_loss: 0.5005 - val_accuracy: 0.7826
# Epoch 11/25
# 11/11 [==============================] - 7s 603ms/step - loss: 0.5046 - accuracy: 0.7629 - val_loss: 0.4169 - val_accuracy: 0.9130
# Epoch 12/25
# 11/11 [==============================] - 7s 635ms/step - loss: 0.4177 - accuracy: 0.8419 - val_loss: 0.2756 - val_accuracy: 0.8986
# Epoch 13/25
# 11/11 [==============================] - 7s 630ms/step - loss: 0.4157 - accuracy: 0.8359 - val_loss: 0.2303 - val_accuracy: 0.9420
# Epoch 14/25
# 11/11 [==============================] - 7s 593ms/step - loss: 0.4378 - accuracy: 0.8085 - val_loss: 0.3004 - val_accuracy: 0.9275
# Epoch 15/25
# 11/11 [==============================] - 7s 631ms/step - loss: 0.4033 - accuracy: 0.8419 - val_loss: 0.3073 - val_accuracy: 0.8841
# Epoch 16/25
# 11/11 [==============================] - 7s 592ms/step - loss: 0.3555 - accuracy: 0.8602 - val_loss: 0.2070 - val_accuracy: 0.9565
# Epoch 17/25
# 11/11 [==============================] - 7s 595ms/step - loss: 0.3565 - accuracy: 0.8359 - val_loss: 0.2307 - val_accuracy: 0.8986
# Epoch 18/25
# 11/11 [==============================] - 7s 609ms/step - loss: 0.3553 - accuracy: 0.8450 - val_loss: 0.2391 - val_accuracy: 0.9275
# Epoch 19/25
# 11/11 [==============================] - 7s 602ms/step - loss: 0.3811 - accuracy: 0.8328 - val_loss: 0.2986 - val_accuracy: 0.8696
# Epoch 20/25
# 11/11 [==============================] - 7s 612ms/step - loss: 0.3622 - accuracy: 0.8419 - val_loss: 0.2804 - val_accuracy: 0.8841
# Epoch 21/25
# 11/11 [==============================] - 7s 631ms/step - loss: 0.3307 - accuracy: 0.8480 - val_loss: 0.2137 - val_accuracy: 0.9420
# Epoch 22/25
# 11/11 [==============================] - 7s 643ms/step - loss: 0.3079 - accuracy: 0.8754 - val_loss: 0.2713 - val_accuracy: 0.8696
# Epoch 23/25
# 11/11 [==============================] - 7s 604ms/step - loss: 0.4558 - accuracy: 0.7933 - val_loss: 0.3697 - val_accuracy: 0.8261
# Epoch 24/25
# 11/11 [==============================] - 7s 604ms/step - loss: 0.4185 - accuracy: 0.8207 - val_loss: 0.3327 - val_accuracy: 0.9130
# Epoch 25/25
# 11/11 [==============================] - 7s 591ms/step - loss: 0.3636 - accuracy: 0.8480 - val_loss: 0.2356 - val_accuracy: 0.9130

# %%
# testing the model
def testing_image(image_directory):
    test_image = image.load_img(image_directory, target_size = (64, 64))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    result = model.predict(x = test_image)
    if result[0][0]  == 1:
        prediction = 'Clean'
    else:
        prediction = 'Messy'
    return prediction

# %%
test_path = []

for filename in os.listdir("dataset/images/test/"):
    test_path.append("dataset/images/test/" + filename)

print("Number of test images: ", len(test_path))
# Out:
# Number of test images:  24

# %%
fig, axs= plt.subplots(2,5, figsize=[24,12])


count=0
for i in range(2):    
    for j in range(5):  
        
        img = cv2.imread(test_path[count])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
       
        txt = "Predict: {:.5}".format(testing_image(test_path[count]))
        
                
        axs[i][j].imshow(img)
        axs[i][j].set_title(txt, fontsize = 14)
        axs[i][j].axis('off')

        count+=1
        
plt.suptitle("All predictions are shown in title", fontsize = 18)        
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c07eccbf-6d55-428d-a5f0-58fc63c83c9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c07eccbf-6d55-428d-a5f0-58fc63c83c9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving anh-3-1552467386-width660height880.jpg to anh-3-1552467386-width660height880.jpg

# %%
path1='/content/anh-3-1552467386-width660height880.jpg'

# %%
img1 = cv2.imread(path1)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
txt = "Predict: {:.5}".format( testing_image(path1))

plt.imshow(img1)
plt.title(txt, fontsize = 20)
plt.axis('off')
plt.show()
